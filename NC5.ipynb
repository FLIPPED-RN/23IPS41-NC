# %%
from keras import datasets,layers,utils,Sequential
import numpy as np
from keras.src.layers import Dense
from keras_tuner.tuners import RandomSearch, Hyperband, BayesianOptimization
from matplotlib.pyplot import step

# %%
(x_train, y_train), (x_test, y_test) = datasets.fashion_mnist.load_data()

# %%
x_train=x_train.reshape(60000,784)
x_test=x_test.reshape(10000, 784)
x_train=x_train/255
x_test=x_test/255
y_train=utils.to_categorical(y_train,10)
y_test=utils.to_categorical(y_test,10)

# %%
def build_model(hp):
    model = Sequential()
    activation_choice = hp.Choice('activation_choice', ['relu', 'tanh', 'sigmoid','elu','selu'])
    model.add(Dense(units=hp.Int('units_input', min_value=512, max_value=1024, step=32), activation=activation_choice,input_dim=784))
    model.add(Dense(units=hp.Int('units_hidden',min_value=128, max_value=600, step=32), activation=activation_choice))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy',
                  optimizer=hp.Choice('optimizer',values=['adam','rmsprop','SGD']), metrics=['accuracy'])
    return model

# %%
tuner=RandomSearch(build_model,objective='val_accuracy',max_trials=80564вп ,directory='test_directory')
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# activation_choice (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh', 'sigmoid', 'elu', 'selu'], 'ordered': False}
# units_input (Int)
# {'default': None, 'conditions': [], 'min_value': 512, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# units_hidden (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 600, 'step': 32, 'sampling': 'linear'}
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'rmsprop', 'SGD'], 'ordered': False}
# C:\Users\Flipper\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tuner.search(x_train,y_train,batch_size=256,epochs=20,validation_split=0.2)
# Out:
# Trial 47 Complete [00h 00m 39s]
# val_accuracy: 0.8462499976158142
#
# Best val_accuracy So Far: 0.8992499709129333
# Total elapsed time: 01h 01m 26s
#
# Search: Running Trial #48
#
# Value             |Best Value So Far |Hyperparameter
# tanh              |relu              |activation_choice
# 704               |576               |units_input
# 320               |320               |units_hidden
# SGD               |adam              |optimizer
#
# Epoch 1/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6612 - loss: 1.0847 - val_accuracy: 0.7557 - val_loss: 0.7592
# Epoch 2/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7709 - loss: 0.6948 - val_accuracy: 0.7828 - val_loss: 0.6387
# Epoch 3/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7969 - loss: 0.6106 - val_accuracy: 0.8023 - val_loss: 0.5831
# Epoch 4/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8099 - loss: 0.5652 - val_accuracy: 0.8123 - val_loss: 0.5501
# Epoch 5/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8193 - loss: 0.5357 - val_accuracy: 0.8177 - val_loss: 0.5269
# Epoch 6/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8253 - loss: 0.5150 - val_accuracy: 0.8189 - val_loss: 0.5119
# Epoch 7/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8294 - loss: 0.4987 - val_accuracy: 0.8265 - val_loss: 0.4963
# Epoch 8/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8329 - loss: 0.4858 - val_accuracy: 0.8274 - val_loss: 0.4880
# Epoch 9/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8365 - loss: 0.4756 - val_accuracy: 0.8289 - val_loss: 0.4789
# Epoch 10/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8384 - loss: 0.4668 - val_accuracy: 0.8328 - val_loss: 0.4701
# Epoch 11/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8403 - loss: 0.4590 - val_accuracy: 0.8347 - val_loss: 0.4634
# Epoch 12/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8427 - loss: 0.4525 - val_accuracy: 0.8361 - val_loss: 0.4586
# Epoch 13/20
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8441 - loss: 0.4468 - val_accuracy: 0.8383 - val_loss: 0.4540
# Epoch 14/20
# 187/188 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8459 - loss: 0.4353
